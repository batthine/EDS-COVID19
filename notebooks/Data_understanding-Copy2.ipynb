# %%
# !ls
# Out:
# Data_prep.ipynb
# Data_understanding-Copy1.ipynb
# Data_understanding-Copy2.ipynb
# Data_understanding-Copy3.ipynb
# Data_understanding.ipynb
# Untitled.ipynb
# Untitled1.ipynb

# %%
# !ls
# Out:
# Data_prep.ipynb
# Data_understanding-Copy1.ipynb
# Data_understanding-Copy2.ipynb
# Data_understanding-Copy3.ipynb
# Data_understanding.ipynb
# Untitled.ipynb
# Untitled1.ipynb

# %% [markdown]
# DATA UNDERSTANDING

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import json
pd.set_option('display.max_rows',500)

# %%
csv_url ="https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/vaccine_data/global_data/time_series_covid19_vaccine_global.csv"

# %%
df=pd.read_csv(csv_url)

# %%
df.tail()
# Out:
#             Country_Region        Date   Doses_admin  \
# 259917  West Bank and Gaza  2022-06-24  3.732571e+06
# 259918               World  2022-06-24  1.164375e+10
# 259919               Yemen  2022-06-24  8.645440e+05
# 259920              Zambia  2022-06-24  6.917310e+06
# 259921            Zimbabwe  2022-06-24  1.189563e+07
#
#         People_partially_vaccinated  People_fully_vaccinated  \
# 259917                          NaN                      NaN
# 259918                 4.993317e+09             4.567549e+09
# 259919                 6.979560e+05             4.461200e+05
# 259920                 3.240892e+06             4.329422e+06
# 259921                 6.281041e+06             4.578232e+06
#
#        Report_Date_String    UID Province_State
# 259917         2022-06-25  275.0            NaN
# 259918         2022-06-25    NaN            NaN
# 259919         2022-06-25  887.0            NaN
# 259920         2022-06-25  894.0            NaN
# ...

# %%
df.keys()
# Out:
# Index(['Country_Region', 'Date', 'Doses_admin', 'People_partially_vaccinated',
#        'People_fully_vaccinated', 'Report_Date_String', 'UID',
#        'Province_State'],
#       dtype='object')

# %%
df_plot = df

# %%
df[df['UID']==276.0].iloc[:,:]
# Out:
#        Country_Region        Date  Doses_admin  People_partially_vaccinated  \
# 97            Germany  2020-12-27      24474.0                      24463.0
# 124           Germany  2020-12-28      42815.0                      42804.0
# 159           Germany  2020-12-29      92364.0                      91764.0
# 195           Germany  2020-12-30     154904.0                     154300.0
# 235           Germany  2020-12-31     204999.0                     204255.0
# ...               ...         ...          ...                          ...
# 256750        Germany  2022-06-20  180588334.0                   64564055.0
# 257424        Germany  2022-06-21  182466948.0                   64565965.0
# 258098        Germany  2022-06-22  182520121.0                   64565965.0
# 258772        Germany  2022-06-23  182520121.0                   64689475.0
# 259446        Germany  2022-06-24  182630015.0                   64692551.0
#
# ...

# %%
df_plot.head()
# Out:
#   Country_Region        Date  Doses_admin  People_partially_vaccinated  \
# 0         Canada  2020-12-14          5.0                          0.0
# 1          World  2020-12-14          5.0                          0.0
# 2         Canada  2020-12-15        723.0                          0.0
# 3          China  2020-12-15    1500000.0                          0.0
# 4         Russia  2020-12-15      28500.0                      28500.0
#
#    People_fully_vaccinated Report_Date_String    UID Province_State
# 0                      0.0         2020-12-14  124.0            NaN
# 1                      0.0         2020-12-14    NaN            NaN
# 2                      0.0         2020-12-15  124.0            NaN
# 3                      0.0         2020-12-15  156.0            NaN
# 4                      0.0         2020-12-15  643.0            NaN

# %%
df_plot.tail()
# Out:
#             Country_Region        Date   Doses_admin  \
# 259917  West Bank and Gaza  2022-06-24  3.732571e+06
# 259918               World  2022-06-24  1.164375e+10
# 259919               Yemen  2022-06-24  8.645440e+05
# 259920              Zambia  2022-06-24  6.917310e+06
# 259921            Zimbabwe  2022-06-24  1.189563e+07
#
#         People_partially_vaccinated  People_fully_vaccinated  \
# 259917                          NaN                      NaN
# 259918                 4.993317e+09             4.567549e+09
# 259919                 6.979560e+05             4.461200e+05
# 259920                 3.240892e+06             4.329422e+06
# 259921                 6.281041e+06             4.578232e+06
#
#        Report_Date_String    UID Province_State
# 259917         2022-06-25  275.0            NaN
# 259918         2022-06-25    NaN            NaN
# 259919         2022-06-25  887.0            NaN
# 259920         2022-06-25  894.0            NaN
# ...

# %%
df_plot.dropna()
# Out:
#                          Country_Region        Date  Doses_admin  \
# 96822                       Afghanistan  2021-10-30    3032521.0
# 96823                           Albania  2021-10-30    1896652.0
# 96824                           Algeria  2021-10-30   11148720.0
# 96825                           Andorra  2021-10-30     102692.0
# 96826                            Angola  2021-10-30    6164219.0
# 96827               Antigua and Barbuda  2021-10-30     105502.0
# 96828                         Argentina  2021-10-30    4796554.0
# 96853                           Armenia  2021-10-30     677032.0
# 96854                         Australia  2021-10-30     887878.0
# 96864                           Austria  2021-10-30   11463818.0
# 96865                        Azerbaijan  2021-10-30    9567956.0
# 96866                           Bahamas  2021-10-30     255085.0
# 96867                           Bahrain  2021-10-30    2766392.0
# ...

# %%
df[df['UID']==276.0].iloc[:,:]
# Out:
#        Country_Region        Date  Doses_admin  People_partially_vaccinated  \
# 97            Germany  2020-12-27      24474.0                      24463.0
# 124           Germany  2020-12-28      42815.0                      42804.0
# 159           Germany  2020-12-29      92364.0                      91764.0
# 195           Germany  2020-12-30     154904.0                     154300.0
# 235           Germany  2020-12-31     204999.0                     204255.0
# ...               ...         ...          ...                          ...
# 256750        Germany  2022-06-20  180588334.0                   64564055.0
# 257424        Germany  2022-06-21  182466948.0                   64565965.0
# 258098        Germany  2022-06-22  182520121.0                   64565965.0
# 258772        Germany  2022-06-23  182520121.0                   64689475.0
# 259446        Germany  2022-06-24  182630015.0                   64692551.0
#
# ...

# %%
df[df['Country_Region']=='Germany']
# Out:
#        Country_Region        Date  Doses_admin  People_partially_vaccinated  \
# 97            Germany  2020-12-27      24474.0                      24463.0
# 124           Germany  2020-12-28      42815.0                      42804.0
# 159           Germany  2020-12-29      92364.0                      91764.0
# 195           Germany  2020-12-30     154904.0                     154300.0
# 235           Germany  2020-12-31     204999.0                     204255.0
# ...               ...         ...          ...                          ...
# 259459        Germany  2022-06-24    7332768.0                          NaN
# 259460        Germany  2022-06-24    4481497.0                          NaN
# 259461        Germany  2022-06-24    7030985.0                          NaN
# 259462        Germany  2022-06-24    4126079.0                          NaN
# 259463        Germany  2022-06-24          0.0                          NaN
#
# ...

# %%
df.Province_State.isnanull
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-153-5cd04707f4ca> in <module>
# ----> 1 df.Province_State.isnanull
#
# C:\Users\Public\Myworkml\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'isnanull'

# %%
df = pd.read_csv(
    'https://raw.githubusercontent.com/govex/COVID-19/master/data_tables/vaccine_data/global_data/time_series_covid19_vaccine_global.csv', 
    usecols=['Country_Region', 'Date', 'People_fully_vaccinated'], 
    parse_dates=['Date'])

# %%
df.head()
# Out:
#   Country_Region       Date  People_fully_vaccinated
# 0         Canada 2020-12-14                      0.0
# 1          World 2020-12-14                      0.0
# 2         Canada 2020-12-15                      0.0
# 3          China 2020-12-15                      0.0
# 4         Russia 2020-12-15                      0.0

# %%
df=df.dropna()

# %%
df_plot=pd.DataFrame({
    'Date':df.Date.unique()})

# %%
df_plot.set_index('Date')
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df.isna()

# %%
df[df['Country_Region']=='Germany'].iloc[:,:]
# Out:
#        Country_Region       Date  People_fully_vaccinated
# 97            Germany 2020-12-27                     11.0
# 124           Germany 2020-12-28                     11.0
# 159           Germany 2020-12-29                    600.0
# 195           Germany 2020-12-30                    604.0
# 235           Germany 2020-12-31                    744.0
# ...               ...        ...                      ...
# 256750        Germany 2022-06-20               64538292.0
# 257424        Germany 2022-06-21               64540917.0
# 258098        Germany 2022-06-22               64540917.0
# 258772        Germany 2022-06-23               63331376.0
# 259446        Germany 2022-06-24               63336470.0
#
# [544 rows x 3 columns]

# %%
df_country.dropna()
# Out:
#            Country_Region  People_fully_vaccinated
# Date
# 2021-01-04          Spain                      0.0
# 2021-01-05          Spain                      0.0
# 2021-01-06          Spain                      0.0
# 2021-01-07          Spain                      0.0
# 2021-01-08          Spain                      0.0
# ...                   ...                      ...
# 2022-06-19          Spain               40539246.0
# 2022-06-20          Spain               40539246.0
# 2022-06-21          Spain               40539246.0
# 2022-06-22          Spain               40539246.0
# 2022-06-23          Spain               40539246.0
#
# [535 rows x 2 columns]

# %%
country_list=['Germany','US','India','Canada','Spain']
for each in country_list:
    df_plot[each]=np.array(df[df['Country_Region']==each].iloc[:,2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-161-cffa46aef6ce> in <module>
#       1 country_list=['Germany','US','India','Canada','Spain']
#       2 for each in country_list:
# ----> 3     df_plot[each]=np.array(df[df['Country_Region']==each].iloc[:,2])
#
# C:\Users\Public\Myworkml\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# C:\Users\Public\Myworkml\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ...

# %%
df_plot.tail(100)

# %%
# %matplotlib inline
df_plot.set_index('Date').plot()
